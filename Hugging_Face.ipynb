# %% [markdown]
# <a href="https://colab.research.google.com/github/mosahle7/ML/blob/main/Hugging_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import BertForSequenceClassification, BertTokenizer
import torch

# %%
model_name = "textattack/bert-base-uncased-imdb"

# %%
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=2)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/511 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
tokenizer = BertTokenizer.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
inputs = tokenizer("I like icecream", return_tensors = "pt")

# %%
inputs
# Out:
# {'input_ids': tensor([[  101,  1045,  2066,  3256, 16748,  3286,   102]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1]])}

# %%
tokens = tokenizer.tokenize("I like icecream")
tokens
# Out:
# ['i', 'like', 'ice', '##cre', '##am']

# %%
with torch.no_grad():
  outputs = model(**inputs).logits
  probs = torch.nn.functional.softmax(outputs,dim=1)
  pred_class = torch.argmax(probs)

if pred_class == 1:
  print(f"Positive ({probs[0][1]*100:.2f})")
else:
  print(f"Negative {(probs[0][0]*100):.2f}")
# Out:
# Positive (76.91)

# %%
# !pip install --upgrade datasets fsspec

from datasets import load_dataset
from IPython.display import HTML,display
# Out:
# ...
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# ...

# %%
dataset = load_dataset("imdb")
# Out:
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
review_no = 42
sample_review = dataset["train"][review_no]

display(HTML(sample_review["text"][:450] + "..."))
# Out:
# WARNING: This review contains SPOILERS. Do not read if you don't want some points revealed to you before you watch the film.<br /><br />With a cast like this, you wonder whether or not the actors and actresses knew exactly what they were getting into. Did they see the script and say, `Hey, Close Encounters of the Third Kind was such a hit that this one can't fail.' Unfortunately, it does. Did they even think to check on the director's credentials...

# %%
if sample_review["label"] == 1:
  print("Positive")
else:
  print("Negative")
# Out:
# Negative

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })

# %% [markdown]
# **Trainers**

# %%
from transformers import(
    DistilBertForSequenceClassification,
    DistilBertTokenizer,
    TrainingArguments,
    Trainer
)

from datasets import load_dataset

# %%
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=2
)

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def tokenizer_fun(egs):
  return tokenizer(egs["text"], padding="max_length",truncation=True)

# %%
dataset = load_dataset("imdb")

# %%
tokenized_datasets = dataset.map(tokenizer_fun, batched=True)
# Out:
# ...
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 50000
#     })
# })

# %%
training_args = TrainingArguments(
    per_device_train_batch_size=64,
    learning_rate=2e-5,
    num_train_epochs = 3,
    output_dir="./results",
    report_to="wandb",
    logging_steps=100,
)

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
)

# %%
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mosahle7 (mosahle7-accenture) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# ...
